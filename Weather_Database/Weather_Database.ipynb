# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d55ef688e590450fd11a4c0290988b6d'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 800

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | jibuti
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | cayenne
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | uvarovka
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | kumluca
# Processing Record 10 of Set 1 | mnogovershinnyy
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | porto novo
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | paro
# Processing Record 20 of Set 1 | kahului
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | norman wells
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | hasaki
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | saint-georges
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | beyneu
# Processing Record 31 of Set 1 | shyryayeve
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 1 | jaen
# Processing Record 35 of Set 1 | cairns
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | henties bay
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | codajas
# Processing Record 42 of Set 1 | rawson
# Processing Record 43 of Set 1 | kingisepp
# Processing Record 44 of Set 1 | karpogory
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | saldanha
# Processing Record 47 of Set 1 | amarante do maranhao
# Processing Record 48 of Set 1 | jardim
# Processing Record 49 of Set 1 | melville
# Processing Record 50 of Set 1 | port moresby
# Processing Record 1 of Set 2 | petrinja
# Processing Record 2 of Set 2 | alta floresta
# Processing Record 3 of Set 2 | port macquarie
# Processing Record 4 of Set 2 | anito
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | vestmanna
# Processing Record 7 of Set 2 | jiaojiang
# Processing Record 8 of Set 2 | wollongong
# Processing Record 9 of Set 2 | klaksvik
# Processing Record 10 of Set 2 | kununurra
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | sosnogorsk
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | acapulco
# Processing Record 18 of Set 2 | eloy
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | itaituba
# Processing Record 28 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | baghdad
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | bitlis
# Processing Record 33 of Set 2 | sambava
# Processing Record 34 of Set 2 | sao borja
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | kharitonovo
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | santa isabel do rio negro
# Processing Record 39 of Set 2 | tilichiki
# Processing Record 40 of Set 2 | leningradskiy
# Processing Record 41 of Set 2 | half moon bay
# Processing Record 42 of Set 2 | coahuayana
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | taoudenni
# Processing Record 45 of Set 2 | morant bay
# Processing Record 46 of Set 2 | noumea
# Processing Record 47 of Set 2 | taicheng
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | bobo dioulasso
# Processing Record 1 of Set 3 | madimba
# Processing Record 2 of Set 3 | san-pedro
# Processing Record 3 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | ahipara
# Processing Record 7 of Set 3 | bani
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | slupsk
# Processing Record 13 of Set 3 | tura
# Processing Record 14 of Set 3 | merauke
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | angostura
# Processing Record 17 of Set 3 | humaita
# Processing Record 18 of Set 3 | ancud
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | anadyr
# Processing Record 22 of Set 3 | tautira
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | zanjan
# Processing Record 26 of Set 3 | poum
# Processing Record 27 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 28 of Set 3 | pierre
# Processing Record 29 of Set 3 | zurrieq
# Processing Record 30 of Set 3 | lata
# Processing Record 31 of Set 3 | ipanema
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | salaga
# Processing Record 34 of Set 3 | concepcion
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | okha
# Processing Record 39 of Set 3 | vila velha
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | san cristobal
# Processing Record 42 of Set 3 | nova vicosa
# Processing Record 43 of Set 3 | rio grande
# Processing Record 44 of Set 3 | kieta
# Processing Record 45 of Set 3 | huntingdon
# Processing Record 46 of Set 3 | nanlong
# Processing Record 47 of Set 3 | san quintin
# Processing Record 48 of Set 3 | demba
# Processing Record 49 of Set 3 | yurty
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | victor harbor
# Processing Record 2 of Set 4 | margate
# Processing Record 3 of Set 4 | mahebourg
# Processing Record 4 of Set 4 | touros
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | hamadan
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | travesia
# Processing Record 9 of Set 4 | korla
# Processing Record 10 of Set 4 | barrow
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | zdunska wola
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | jilib
# Processing Record 16 of Set 4 | baracoa
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | zhicheng
# Processing Record 19 of Set 4 | epiniana
# Processing Record 20 of Set 4 | vaini
# Processing Record 21 of Set 4 | san rafael
# Processing Record 22 of Set 4 | maku
# Processing Record 23 of Set 4 | toro
# Processing Record 24 of Set 4 | nizwa
# Processing Record 25 of Set 4 | laguna
# Processing Record 26 of Set 4 | tselinnoye
# Processing Record 27 of Set 4 | el rosario
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | vestmannaeyjar
# Processing Record 30 of Set 4 | rehoboth
# Processing Record 31 of Set 4 | nairn
# Processing Record 32 of Set 4 | haimen
# Processing Record 33 of Set 4 | surman
# Processing Record 34 of Set 4 | mount gambier
# Processing Record 35 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 36 of Set 4 | shajapur
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | skeldon
# Processing Record 39 of Set 4 | telde
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 4 | neryungri
# Processing Record 43 of Set 4 | hobyo
# Processing Record 44 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 4 | sao joao da barra
# Processing Record 46 of Set 4 | otradnoye
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | talaya
# Processing Record 49 of Set 4 | flinders
# Processing Record 50 of Set 4 | dagana
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | leiyang
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | sinnamary
# Processing Record 5 of Set 5 | lady frere
# Processing Record 6 of Set 5 | mubi
# Processing Record 7 of Set 5 | alvorada
# Processing Record 8 of Set 5 | alofi
# Processing Record 9 of Set 5 | santo antonio do ica
# Processing Record 10 of Set 5 | peleduy
# Processing Record 11 of Set 5 | hervey bay
# Processing Record 12 of Set 5 | yellowknife
# Processing Record 13 of Set 5 | san andres
# Processing Record 14 of Set 5 | takanabe
# Processing Record 15 of Set 5 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | parry sound
# Processing Record 18 of Set 5 | sibolga
# Processing Record 19 of Set 5 | husavik
# Processing Record 20 of Set 5 | senmonorom
# City not found. Skipping...
# Processing Record 21 of Set 5 | talara
# Processing Record 22 of Set 5 | chokwe
# Processing Record 23 of Set 5 | bonthe
# Processing Record 24 of Set 5 | karanganyar
# Processing Record 25 of Set 5 | beringovskiy
# Processing Record 26 of Set 5 | weihai
# Processing Record 27 of Set 5 | balaka
# Processing Record 28 of Set 5 | shelburne
# Processing Record 29 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 5 | stockerau
# Processing Record 32 of Set 5 | port lincoln
# Processing Record 33 of Set 5 | helong
# Processing Record 34 of Set 5 | zhigansk
# Processing Record 35 of Set 5 | nerchinskiy zavod
# Processing Record 36 of Set 5 | tabas
# Processing Record 37 of Set 5 | vitim
# Processing Record 38 of Set 5 | ust-kulom
# Processing Record 39 of Set 5 | jieshi
# Processing Record 40 of Set 5 | coquimbo
# Processing Record 41 of Set 5 | broome
# Processing Record 42 of Set 5 | kawalu
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | birnin kebbi
# Processing Record 45 of Set 5 | okoneshnikovo
# Processing Record 46 of Set 5 | nakhon phanom
# Processing Record 47 of Set 5 | baruun-urt
# Processing Record 48 of Set 5 | rafaela
# Processing Record 49 of Set 5 | rapid valley
# Processing Record 50 of Set 5 | sibu
# Processing Record 1 of Set 6 | santa maria
# Processing Record 2 of Set 6 | kuusamo
# Processing Record 3 of Set 6 | mana
# Processing Record 4 of Set 6 | syracuse
# Processing Record 5 of Set 6 | tahe
# Processing Record 6 of Set 6 | tessalit
# Processing Record 7 of Set 6 | luderitz
# Processing Record 8 of Set 6 | maykor
# Processing Record 9 of Set 6 | roald
# Processing Record 10 of Set 6 | batemans bay
# Processing Record 11 of Set 6 | berdigestyakh
# Processing Record 12 of Set 6 | beloha
# Processing Record 13 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 14 of Set 6 | samfya
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | kapoeta
# Processing Record 17 of Set 6 | sivas
# Processing Record 18 of Set 6 | villa bruzual
# Processing Record 19 of Set 6 | pevek
# Processing Record 20 of Set 6 | qasigiannguit
# Processing Record 21 of Set 6 | ulaangom
# Processing Record 22 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 23 of Set 6 | naze
# Processing Record 24 of Set 6 | hovd
# Processing Record 25 of Set 6 | avare
# Processing Record 26 of Set 6 | mangrol
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | tiksi
# Processing Record 29 of Set 6 | irara
# Processing Record 30 of Set 6 | paamiut
# Processing Record 31 of Set 6 | stornoway
# Processing Record 32 of Set 6 | geraldton
# Processing Record 33 of Set 6 | bokoro
# Processing Record 34 of Set 6 | nantucket
# Processing Record 35 of Set 6 | northallerton
# Processing Record 36 of Set 6 | constitucion
# Processing Record 37 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 6 | nabire
# Processing Record 39 of Set 6 | nouadhibou
# Processing Record 40 of Set 6 | portland
# Processing Record 41 of Set 6 | turayf
# Processing Record 42 of Set 6 | saint-leu
# Processing Record 43 of Set 6 | burica
# City not found. Skipping...
# Processing Record 44 of Set 6 | vanavara
# Processing Record 45 of Set 6 | santa helena de goias
# Processing Record 46 of Set 6 | guia de isora
# Processing Record 47 of Set 6 | kaohsiung
# Processing Record 48 of Set 6 | fort nelson
# Processing Record 49 of Set 6 | shirokiy
# Processing Record 50 of Set 6 | namibe
# Processing Record 1 of Set 7 | lang son
# Processing Record 2 of Set 7 | maldonado
# Processing Record 3 of Set 7 | dauphin
# Processing Record 4 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 7 | makakilo city
# Processing Record 6 of Set 7 | kavaratti
# Processing Record 7 of Set 7 | bathsheba
# Processing Record 8 of Set 7 | gamba
# Processing Record 9 of Set 7 | ullubiyaul
# Processing Record 10 of Set 7 | coihaique
# Processing Record 11 of Set 7 | havre-saint-pierre
# Processing Record 12 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 7 | xai-xai
# Processing Record 14 of Set 7 | schotten
# Processing Record 15 of Set 7 | dwarka
# Processing Record 16 of Set 7 | kargasok
# Processing Record 17 of Set 7 | mmathubudukwane
# Processing Record 18 of Set 7 | axim
# Processing Record 19 of Set 7 | celestun
# Processing Record 20 of Set 7 | togur
# Processing Record 21 of Set 7 | enshi
# Processing Record 22 of Set 7 | balikpapan
# Processing Record 23 of Set 7 | karaton
# Processing Record 24 of Set 7 | malanville
# Processing Record 25 of Set 7 | beroroha
# Processing Record 26 of Set 7 | yishui
# Processing Record 27 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 28 of Set 7 | east london
# Processing Record 29 of Set 7 | khandyga
# Processing Record 30 of Set 7 | flin flon
# Processing Record 31 of Set 7 | lagos
# Processing Record 32 of Set 7 | ubauro
# Processing Record 33 of Set 7 | roma
# Processing Record 34 of Set 7 | caravelas
# Processing Record 35 of Set 7 | yulara
# Processing Record 36 of Set 7 | nazarovo
# Processing Record 37 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 38 of Set 7 | hofn
# Processing Record 39 of Set 7 | vardo
# Processing Record 40 of Set 7 | hamilton
# Processing Record 41 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 42 of Set 7 | sai buri
# Processing Record 43 of Set 7 | peruibe
# Processing Record 44 of Set 7 | melilla
# Processing Record 45 of Set 7 | pachino
# Processing Record 46 of Set 7 | karasjok
# Processing Record 47 of Set 7 | iisalmi
# Processing Record 48 of Set 7 | manta
# Processing Record 49 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 7 | kavieng
# Processing Record 1 of Set 8 | newcastle
# Processing Record 2 of Set 8 | ust-nera
# Processing Record 3 of Set 8 | chapais
# Processing Record 4 of Set 8 | pergine valsugana
# Processing Record 5 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 8 | pingzhuang
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | tateyama
# Processing Record 9 of Set 8 | omsukchan
# Processing Record 10 of Set 8 | phetchaburi
# Processing Record 11 of Set 8 | gao
# Processing Record 12 of Set 8 | nome
# Processing Record 13 of Set 8 | high level
# Processing Record 14 of Set 8 | aklavik
# Processing Record 15 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 8 | sakaiminato
# Processing Record 17 of Set 8 | inuvik
# Processing Record 18 of Set 8 | richards bay
# Processing Record 19 of Set 8 | gat
# Processing Record 20 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 21 of Set 8 | nyrob
# Processing Record 22 of Set 8 | nelson bay
# Processing Record 23 of Set 8 | conceicao do mato dentro
# Processing Record 24 of Set 8 | svetlaya
# Processing Record 25 of Set 8 | jahrom
# City not found. Skipping...
# Processing Record 26 of Set 8 | andarab
# City not found. Skipping...
# Processing Record 27 of Set 8 | kulhudhuffushi
# Processing Record 28 of Set 8 | mersing
# Processing Record 29 of Set 8 | kalmunai
# Processing Record 30 of Set 8 | tortoli
# Processing Record 31 of Set 8 | kashi
# Processing Record 32 of Set 8 | san patricio
# Processing Record 33 of Set 8 | aykhal
# Processing Record 34 of Set 8 | mtwara
# Processing Record 35 of Set 8 | walvis bay
# Processing Record 36 of Set 8 | thompson
# Processing Record 37 of Set 8 | aksu
# Processing Record 38 of Set 8 | ilulissat
# Processing Record 39 of Set 8 | bazarnyye mataki
# Processing Record 40 of Set 8 | salalah
# Processing Record 41 of Set 8 | northam
# Processing Record 42 of Set 8 | badvel
# Processing Record 43 of Set 8 | sorgun
# Processing Record 44 of Set 8 | vanderhoof
# Processing Record 45 of Set 8 | kikwit
# Processing Record 46 of Set 8 | bambous virieux
# Processing Record 47 of Set 8 | isangel
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | presidencia roque saenz pena
# Processing Record 50 of Set 8 | letlhakane
# Processing Record 1 of Set 9 | karratha
# Processing Record 2 of Set 9 | kerrville
# Processing Record 3 of Set 9 | kristiinankaupunki
# Processing Record 4 of Set 9 | kincardine
# Processing Record 5 of Set 9 | lasa
# Processing Record 6 of Set 9 | luganville
# Processing Record 7 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 9 | scarborough
# Processing Record 9 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | lensk
# Processing Record 11 of Set 9 | qaqortoq
# Processing Record 12 of Set 9 | kaeo
# Processing Record 13 of Set 9 | quatre cocos
# Processing Record 14 of Set 9 | banda aceh
# Processing Record 15 of Set 9 | xiongzhou
# Processing Record 16 of Set 9 | marsh harbour
# Processing Record 17 of Set 9 | arawa
# Processing Record 18 of Set 9 | gravdal
# Processing Record 19 of Set 9 | carlagan
# Processing Record 20 of Set 9 | pitkyaranta
# Processing Record 21 of Set 9 | tromso
# Processing Record 22 of Set 9 | traverse city
# Processing Record 23 of Set 9 | rosamorada
# Processing Record 24 of Set 9 | yola
# Processing Record 25 of Set 9 | nancha
# Processing Record 26 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 9 | charters towers
# Processing Record 28 of Set 9 | koraput
# Processing Record 29 of Set 9 | chumikan
# Processing Record 30 of Set 9 | yuli
# Processing Record 31 of Set 9 | sfantu gheorghe
# Processing Record 32 of Set 9 | ukiah
# Processing Record 33 of Set 9 | dickinson
# Processing Record 34 of Set 9 | medina del campo
# Processing Record 35 of Set 9 | lar
# Processing Record 36 of Set 9 | farafangana
# Processing Record 37 of Set 9 | mont-dore
# Processing Record 38 of Set 9 | yokadouma
# Processing Record 39 of Set 9 | fatehpur
# Processing Record 40 of Set 9 | sardulgarh
# Processing Record 41 of Set 9 | bloomfield
# Processing Record 42 of Set 9 | tra vinh
# Processing Record 43 of Set 9 | monopoli
# Processing Record 44 of Set 9 | abaza
# Processing Record 45 of Set 9 | antalaha
# Processing Record 46 of Set 9 | chulym
# Processing Record 47 of Set 9 | codrington
# Processing Record 48 of Set 9 | christchurch
# Processing Record 49 of Set 9 | cururupu
# Processing Record 50 of Set 9 | guerrero negro
# Processing Record 1 of Set 10 | buala
# Processing Record 2 of Set 10 | saboya
# Processing Record 3 of Set 10 | angoche
# Processing Record 4 of Set 10 | kizner
# Processing Record 5 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 6 of Set 10 | yar-sale
# Processing Record 7 of Set 10 | grand gaube
# Processing Record 8 of Set 10 | ketchikan
# Processing Record 9 of Set 10 | kantunilkin
# Processing Record 10 of Set 10 | honiara
# Processing Record 11 of Set 10 | powell river
# Processing Record 12 of Set 10 | vao
# Processing Record 13 of Set 10 | college
# Processing Record 14 of Set 10 | cabedelo
# Processing Record 15 of Set 10 | chernyshevskiy
# Processing Record 16 of Set 10 | zhezkazgan
# Processing Record 17 of Set 10 | hambantota
# Processing Record 18 of Set 10 | chuy
# Processing Record 19 of Set 10 | qitaihe
# Processing Record 20 of Set 10 | atambua
# Processing Record 21 of Set 10 | sorong
# Processing Record 22 of Set 10 | kiunga
# Processing Record 23 of Set 10 | atasu
# Processing Record 24 of Set 10 | saulkrasti
# Processing Record 25 of Set 10 | pochutla
# Processing Record 26 of Set 10 | crixas
# Processing Record 27 of Set 10 | mount pleasant
# Processing Record 28 of Set 10 | belaya gora
# Processing Record 29 of Set 10 | bandarbeyla
# Processing Record 30 of Set 10 | szentgotthard
# Processing Record 31 of Set 10 | port-cartier
# Processing Record 32 of Set 10 | kyren
# Processing Record 33 of Set 10 | uthal
# Processing Record 34 of Set 10 | elizabeth city
# Processing Record 35 of Set 10 | manicore
# Processing Record 36 of Set 10 | kutum
# Processing Record 37 of Set 10 | chara
# Processing Record 38 of Set 10 | sorata
# Processing Record 39 of Set 10 | oum hadjer
# Processing Record 40 of Set 10 | brae
# Processing Record 41 of Set 10 | jacareacanga
# Processing Record 42 of Set 10 | srednekolymsk
# Processing Record 43 of Set 10 | opuwo
# Processing Record 44 of Set 10 | lompoc
# Processing Record 45 of Set 10 | samana
# Processing Record 46 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 47 of Set 10 | ondjiva
# Processing Record 48 of Set 10 | tyup
# Processing Record 49 of Set 10 | kropotkin
# Processing Record 50 of Set 10 | lucapa
# Processing Record 1 of Set 11 | tamandare
# Processing Record 2 of Set 11 | corowa
# Processing Record 3 of Set 11 | veere
# Processing Record 4 of Set 11 | beisfjord
# Processing Record 5 of Set 11 | bowen
# Processing Record 6 of Set 11 | craigieburn
# Processing Record 7 of Set 11 | illapel
# Processing Record 8 of Set 11 | verkhnyaya inta
# Processing Record 9 of Set 11 | pemba
# Processing Record 10 of Set 11 | tyumentsevo
# Processing Record 11 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 11 | djenne
# Processing Record 13 of Set 11 | honningsvag
# Processing Record 14 of Set 11 | dubuque
# Processing Record 15 of Set 11 | omutinskoye
# City not found. Skipping...
# Processing Record 16 of Set 11 | samarai
# Processing Record 17 of Set 11 | bilibino
# Processing Record 18 of Set 11 | bitkine
# Processing Record 19 of Set 11 | tocopilla
# Processing Record 20 of Set 11 | ouegoa
# Processing Record 21 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 22 of Set 11 | riviere-au-renard
# Processing Record 23 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 11 | changji
# Processing Record 25 of Set 11 | santa cruz
# Processing Record 26 of Set 11 | putina
# Processing Record 27 of Set 11 | lashio
# Processing Record 28 of Set 11 | sansai
# City not found. Skipping...
# Processing Record 29 of Set 11 | sayyan
# Processing Record 30 of Set 11 | vila do maio
# Processing Record 31 of Set 11 | ati
# Processing Record 32 of Set 11 | guiglo
# Processing Record 33 of Set 11 | komsomolskiy
# Processing Record 34 of Set 11 | tuy hoa
# Processing Record 35 of Set 11 | evensk
# Processing Record 36 of Set 11 | ciudad bolivar
# Processing Record 37 of Set 11 | cap malheureux
# Processing Record 38 of Set 11 | longhua
# Processing Record 39 of Set 11 | verkhoyansk
# Processing Record 40 of Set 11 | kovdor
# Processing Record 41 of Set 11 | sao mateus
# Processing Record 42 of Set 11 | sayat
# Processing Record 43 of Set 11 | pangnirtung
# Processing Record 44 of Set 11 | quelimane
# Processing Record 45 of Set 11 | puerto maldonado
# Processing Record 46 of Set 11 | khalkhal
# Processing Record 47 of Set 11 | taitung
# Processing Record 48 of Set 11 | faanui
# Processing Record 49 of Set 11 | lagoa
# Processing Record 50 of Set 11 | sarany
# Processing Record 1 of Set 12 | yarada
# Processing Record 2 of Set 12 | venice
# Processing Record 3 of Set 12 | tuzla
# Processing Record 4 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 12 | luis correia
# Processing Record 6 of Set 12 | aripuana
# Processing Record 7 of Set 12 | natal
# Processing Record 8 of Set 12 | joshimath
# Processing Record 9 of Set 12 | salisbury
# Processing Record 10 of Set 12 | lazaro cardenas
# Processing Record 11 of Set 12 | batagay
# Processing Record 12 of Set 12 | barra velha
# Processing Record 13 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 12 | mayo
# Processing Record 15 of Set 12 | liwonde
# Processing Record 16 of Set 12 | nanakuli
# Processing Record 17 of Set 12 | salym
# Processing Record 18 of Set 12 | gladstone
# Processing Record 19 of Set 12 | port blair
# Processing Record 20 of Set 12 | ambon
# Processing Record 21 of Set 12 | goya
# Processing Record 22 of Set 12 | dod ballapur
# Processing Record 23 of Set 12 | skibbereen
# Processing Record 24 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 12 | ust-kuyga
# Processing Record 26 of Set 12 | imbituba
# Processing Record 27 of Set 12 | ostrovnoy
# Processing Record 28 of Set 12 | arrifes
# Processing Record 29 of Set 12 | meulaboh
# Processing Record 30 of Set 12 | vallenar
# Processing Record 31 of Set 12 | namatanai
# Processing Record 32 of Set 12 | lamar
# Processing Record 33 of Set 12 | rocha
# Processing Record 34 of Set 12 | porto santo
# Processing Record 35 of Set 12 | kungurtug
# Processing Record 36 of Set 12 | necochea
# Processing Record 37 of Set 12 | tenosique
# Processing Record 38 of Set 12 | auki
# Processing Record 39 of Set 12 | bundaberg
# Processing Record 40 of Set 12 | ossora
# Processing Record 41 of Set 12 | redlands
# Processing Record 42 of Set 12 | bambanglipuro
# Processing Record 43 of Set 12 | nara
# Processing Record 44 of Set 12 | aswan
# Processing Record 45 of Set 12 | nalut
# Processing Record 46 of Set 12 | bangkalan
# Processing Record 47 of Set 12 | orahovac
# Processing Record 48 of Set 12 | carballo
# Processing Record 49 of Set 12 | ridgecrest
# Processing Record 50 of Set 12 | asau
# Processing Record 1 of Set 13 | bay roberts
# Processing Record 2 of Set 13 | mongomo
# Processing Record 3 of Set 13 | kalabo
# Processing Record 4 of Set 13 | teguise
# Processing Record 5 of Set 13 | chimore
# Processing Record 6 of Set 13 | shangzhi
# Processing Record 7 of Set 13 | altay
# Processing Record 8 of Set 13 | zalantun
# Processing Record 9 of Set 13 | ikot ekpene
# Processing Record 10 of Set 13 | turukhansk
# Processing Record 11 of Set 13 | druzhba
# Processing Record 12 of Set 13 | leh
# Processing Record 13 of Set 13 | terra santa
# Processing Record 14 of Set 13 | troitskoye
# Processing Record 15 of Set 13 | makokou
# Processing Record 16 of Set 13 | ladysmith
# Processing Record 17 of Set 13 | rees
# Processing Record 18 of Set 13 | palmer
# Processing Record 19 of Set 13 | kibala
# Processing Record 20 of Set 13 | kuragino
# Processing Record 21 of Set 13 | kampot
# Processing Record 22 of Set 13 | sioux lookout
# Processing Record 23 of Set 13 | kichera
# Processing Record 24 of Set 13 | yarqa
# Processing Record 25 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 13 | atikokan
# Processing Record 27 of Set 13 | waiouru
# Processing Record 28 of Set 13 | kovur
# Processing Record 29 of Set 13 | sucua
# Processing Record 30 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 13 | lanzhou
# Processing Record 32 of Set 13 | mgandu
# Processing Record 33 of Set 13 | ust-ilimsk
# Processing Record 34 of Set 13 | emerald
# Processing Record 35 of Set 13 | harnosand
# Processing Record 36 of Set 13 | alma
# Processing Record 37 of Set 13 | limulunga
# Processing Record 38 of Set 13 | katobu
# Processing Record 39 of Set 13 | souillac
# Processing Record 40 of Set 13 | itarema
# Processing Record 41 of Set 13 | dicabisagan
# Processing Record 42 of Set 13 | nishihara
# Processing Record 43 of Set 13 | buraydah
# Processing Record 44 of Set 13 | hondagua
# Processing Record 45 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 13 | acari
# Processing Record 47 of Set 13 | mantua
# Processing Record 48 of Set 13 | manono
# Processing Record 49 of Set 13 | ternate
# Processing Record 50 of Set 13 | goderich
# Processing Record 1 of Set 14 | chebenki
# Processing Record 2 of Set 14 | urucui
# Processing Record 3 of Set 14 | impfondo
# Processing Record 4 of Set 14 | vite
# Processing Record 5 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 14 | warren
# Processing Record 7 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 14 | sarai naurang
# Processing Record 9 of Set 14 | plettenberg bay
# Processing Record 10 of Set 14 | puerto del rosario
# Processing Record 11 of Set 14 | pak phanang
# Processing Record 12 of Set 14 | comodoro rivadavia
# Processing Record 13 of Set 14 | cody
# Processing Record 14 of Set 14 | santiago del estero
# Processing Record 15 of Set 14 | nyimba
# Processing Record 16 of Set 14 | oktyabrskoye
# Processing Record 17 of Set 14 | katsuura
# Processing Record 18 of Set 14 | tunduma
# Processing Record 19 of Set 14 | narsaq
# Processing Record 20 of Set 14 | suntar
# Processing Record 21 of Set 14 | ligayan
# Processing Record 22 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 23 of Set 14 | kirensk
# Processing Record 24 of Set 14 | algiers
# Processing Record 25 of Set 14 | mazatlan
# Processing Record 26 of Set 14 | anloga
# Processing Record 27 of Set 14 | maragogi
# Processing Record 28 of Set 14 | hutchinson
# Processing Record 29 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 14 | halifax
# Processing Record 32 of Set 14 | sri aman
# Processing Record 33 of Set 14 | salinopolis
# Processing Record 34 of Set 14 | alta gracia
# Processing Record 35 of Set 14 | ust-maya
# Processing Record 36 of Set 14 | huilong
# Processing Record 37 of Set 14 | dunedin
# Processing Record 38 of Set 14 | lodwar
# Processing Record 39 of Set 14 | soyo
# Processing Record 40 of Set 14 | nioro
# Processing Record 41 of Set 14 | alghero
# Processing Record 42 of Set 14 | panlaitan
# Processing Record 43 of Set 14 | kazanskaya
# Processing Record 44 of Set 14 | kemerovo
# Processing Record 45 of Set 14 | urumqi
# Processing Record 46 of Set 14 | ballina
# Processing Record 47 of Set 14 | pontianak
# Processing Record 48 of Set 14 | eyl
# Processing Record 49 of Set 14 | synya
# Processing Record 50 of Set 14 | waipawa
# Processing Record 1 of Set 15 | mindif
# Processing Record 2 of Set 15 | kisesa
# Processing Record 3 of Set 15 | batagay-alyta
# Processing Record 4 of Set 15 | sabang
# Processing Record 5 of Set 15 | taft
# Processing Record 6 of Set 15 | warrington
# Processing Record 7 of Set 15 | teya
# Processing Record 8 of Set 15 | makkaveyevo
# Processing Record 9 of Set 15 | usinsk
# Processing Record 10 of Set 15 | sainte-marie
# Processing Record 11 of Set 15 | upata
# Processing Record 12 of Set 15 | novaya igirma
# Processing Record 13 of Set 15 | labuhan
# Processing Record 14 of Set 15 | pasni
# Processing Record 15 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 16 of Set 15 | millinocket
# Processing Record 17 of Set 15 | garowe
# Processing Record 18 of Set 15 | rio cuarto
# Processing Record 19 of Set 15 | brownsville
# Processing Record 20 of Set 15 | sawakin
# Processing Record 21 of Set 15 | saint anthony
# Processing Record 22 of Set 15 | dezhou
# Processing Record 23 of Set 15 | nisia floresta
# Processing Record 24 of Set 15 | steinbach
# Processing Record 25 of Set 15 | vilhena
# Processing Record 26 of Set 15 | filadelfia
# Processing Record 27 of Set 15 | havoysund
# Processing Record 28 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 15 | helmsdale
# Processing Record 30 of Set 15 | willowmore
# Processing Record 31 of Set 15 | puerto carreno
# Processing Record 32 of Set 15 | dispur
# Processing Record 33 of Set 15 | challapata
# Processing Record 34 of Set 15 | cabra
# Processing Record 35 of Set 15 | mackay
# Processing Record 36 of Set 15 | sandpoint
# Processing Record 37 of Set 15 | aktau
# Processing Record 38 of Set 15 | fare
# Processing Record 39 of Set 15 | chicama
# Processing Record 40 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 15 | huarmey
# Processing Record 42 of Set 15 | khanewal
# Processing Record 43 of Set 15 | mamlyutka
# Processing Record 44 of Set 15 | hays
# Processing Record 45 of Set 15 | bourail
# Processing Record 46 of Set 15 | ous
# Processing Record 47 of Set 15 | marovoay
# Processing Record 48 of Set 15 | san policarpo
# Processing Record 49 of Set 15 | mitu
# Processing Record 50 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 16 | pinheiro machado
# Processing Record 2 of Set 16 | naini tal
# Processing Record 3 of Set 16 | iquique
# Processing Record 4 of Set 16 | waverly
# Processing Record 5 of Set 16 | angra
# City not found. Skipping...
# Processing Record 6 of Set 16 | belton
# Processing Record 7 of Set 16 | amga
# Processing Record 8 of Set 16 | snasa
# Processing Record 9 of Set 16 | yaounde
# Processing Record 10 of Set 16 | padang
# Processing Record 11 of Set 16 | paraiso
# Processing Record 12 of Set 16 | marquette
# Processing Record 13 of Set 16 | sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 16 | valdosta
# Processing Record 15 of Set 16 | iskateley
# Processing Record 16 of Set 16 | port hedland
# Processing Record 17 of Set 16 | temiscaming
# Processing Record 18 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 16 | malakal
# Processing Record 20 of Set 16 | camanci
# City not found. Skipping...
# Processing Record 21 of Set 16 | anzio
# Processing Record 22 of Set 16 | ndele
# Processing Record 23 of Set 16 | novooleksiyivka
# Processing Record 24 of Set 16 | luanda
# Processing Record 25 of Set 16 | shitanjing
# Processing Record 26 of Set 16 | vanino
# Processing Record 27 of Set 16 | kaseda
# Processing Record 28 of Set 16 | kozhva
# Processing Record 29 of Set 16 | pangkalanbuun
# Processing Record 30 of Set 16 | chanthaburi
# Processing Record 31 of Set 16 | naerbo
# Processing Record 32 of Set 16 | paracuru
# Processing Record 33 of Set 16 | mozarlandia
# Processing Record 34 of Set 16 | qingdao
# Processing Record 35 of Set 16 | la paz
# Processing Record 36 of Set 16 | ambanja
# Processing Record 37 of Set 16 | balykshi
# Processing Record 38 of Set 16 | uporovo
# Processing Record 39 of Set 16 | elat
# Processing Record 40 of Set 16 | kigoma
# Processing Record 41 of Set 16 | sistranda
# Processing Record 42 of Set 16 | san carlos de bariloche
# Processing Record 43 of Set 16 | bereda
# Processing Record 44 of Set 16 | sigerfjord
# City not found. Skipping...
# Processing Record 45 of Set 16 | porto velho
# Processing Record 46 of Set 16 | la flecha
# Processing Record 47 of Set 16 | sola
# Processing Record 48 of Set 16 | aasiaat
# Processing Record 49 of Set 16 | imeni poliny osipenko
# Processing Record 50 of Set 16 | maningrida
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Jibuti  11.5000   42.5000     67.42        56           5
# 1          Iqaluit  63.7506  -68.5145    -16.87        52          75
# 2          Cayenne   4.9333  -52.3333     79.09        88           0
# 3   Severo-Kurilsk  50.6789  156.1250     29.75        92         100
# 4         Uvarovka  55.5278   35.6061     14.63        98         100
# 5            Bluff -46.6000  168.3333     55.80        58          93
# 6        Cape Town -33.9258   18.4232     65.88        64           0
# 7          Kumluca  36.3703   30.2869     45.68        50          63
# 8  Mnogovershinnyy  53.9353  139.9242     -2.27        96         100
# 9       Butaritari   3.0707  172.7902     82.65        75          17
#
#    Wind Speed Country Current Description
# 0        6.62      DJ           clear sky
# 1        4.61      CA       broken clouds
# 2        1.99      GF           clear sky
# 3        6.64      RU          light snow
# 4        1.25      RU     overcast clouds
# 5        6.02      NZ     overcast clouds
# 6        1.99      ZA           clear sky
# 7        8.21      TR       broken clouds
# 8        6.49      RU     overcast clouds
# 9       18.28      KI          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
