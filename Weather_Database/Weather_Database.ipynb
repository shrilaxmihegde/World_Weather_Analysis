# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d55ef688e590450fd11a4c0290988b6d'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | miri
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | avera
# Processing Record 4 of Set 1 | burica
# City not found. Skipping...
# Processing Record 5 of Set 1 | takab
# Processing Record 6 of Set 1 | santo tomas
# Processing Record 7 of Set 1 | balkhash
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | adrar
# Processing Record 11 of Set 1 | lorengau
# Processing Record 12 of Set 1 | iwaki
# Processing Record 13 of Set 1 | cayenne
# Processing Record 14 of Set 1 | saint-pierre
# Processing Record 15 of Set 1 | kikwit
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | jhudo
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | agua verde
# Processing Record 22 of Set 1 | dumas
# Processing Record 23 of Set 1 | husavik
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | hualmay
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 1 | ventspils
# Processing Record 31 of Set 1 | mangrol
# Processing Record 32 of Set 1 | sterling
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | maniitsoq
# Processing Record 37 of Set 1 | karakol
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | yar-sale
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | tabou
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | nishihara
# Processing Record 47 of Set 1 | sao joao da barra
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | tautira
# Processing Record 50 of Set 1 | bratsk
# Processing Record 1 of Set 2 | nabire
# Processing Record 2 of Set 2 | hasaki
# Processing Record 3 of Set 2 | koboldo
# City not found. Skipping...
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | vernon
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | chicama
# Processing Record 10 of Set 2 | nouadhibou
# Processing Record 11 of Set 2 | sao filipe
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | lyaskelya
# Processing Record 14 of Set 2 | krasnovishersk
# Processing Record 15 of Set 2 | port lincoln
# Processing Record 16 of Set 2 | farafangana
# Processing Record 17 of Set 2 | hobyo
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | ler
# Processing Record 20 of Set 2 | luwuk
# Processing Record 21 of Set 2 | bambous virieux
# Processing Record 22 of Set 2 | pisco
# Processing Record 23 of Set 2 | puerto baquerizo moreno
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | tyulgan
# Processing Record 28 of Set 2 | kishi
# Processing Record 29 of Set 2 | braslav
# City not found. Skipping...
# Processing Record 30 of Set 2 | pevek
# Processing Record 31 of Set 2 | vostok
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | punta arenas
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | douglas
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | vagur
# Processing Record 40 of Set 2 | vardo
# Processing Record 41 of Set 2 | marsa matruh
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | lavrentiya
# Processing Record 45 of Set 2 | vao
# Processing Record 46 of Set 2 | mzimba
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | la ronge
# Processing Record 50 of Set 2 | waipawa
# Processing Record 1 of Set 3 | sulingen
# Processing Record 2 of Set 3 | butembo
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | gornopravdinsk
# Processing Record 5 of Set 3 | lukovetskiy
# Processing Record 6 of Set 3 | tsiroanomandidy
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | kudahuvadhoo
# Processing Record 9 of Set 3 | roma
# Processing Record 10 of Set 3 | yarada
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | hays
# Processing Record 16 of Set 3 | amapa
# Processing Record 17 of Set 3 | novo horizonte
# Processing Record 18 of Set 3 | mata
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | mizpe ramon
# City not found. Skipping...
# Processing Record 21 of Set 3 | esperance
# Processing Record 22 of Set 3 | malanje
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | ongandjera
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | eenhana
# Processing Record 29 of Set 3 | saldanha
# Processing Record 30 of Set 3 | garissa
# Processing Record 31 of Set 3 | georgiyevka
# Processing Record 32 of Set 3 | kenai
# Processing Record 33 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 3 | goderich
# Processing Record 35 of Set 3 | itaituba
# Processing Record 36 of Set 3 | poyarkovo
# Processing Record 37 of Set 3 | jahrom
# City not found. Skipping...
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | abay
# Processing Record 40 of Set 3 | miranda
# Processing Record 41 of Set 3 | zhifang
# Processing Record 42 of Set 3 | obo
# Processing Record 43 of Set 3 | rognan
# Processing Record 44 of Set 3 | olafsvik
# Processing Record 45 of Set 3 | jacareacanga
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | ocampo
# Processing Record 48 of Set 3 | santa cruz do sul
# Processing Record 49 of Set 3 | lichtenburg
# Processing Record 50 of Set 3 | saskylakh
# Processing Record 1 of Set 4 | kirakira
# Processing Record 2 of Set 4 | umm lajj
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | atambua
# Processing Record 5 of Set 4 | bluff
# Processing Record 6 of Set 4 | srednekolymsk
# Processing Record 7 of Set 4 | trinidad
# Processing Record 8 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 4 | ilulissat
# Processing Record 10 of Set 4 | padang
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | zhangye
# Processing Record 13 of Set 4 | mundo nuevo
# Processing Record 14 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 4 | puerto berrio
# Processing Record 16 of Set 4 | baruun-urt
# Processing Record 17 of Set 4 | sakakah
# Processing Record 18 of Set 4 | poum
# Processing Record 19 of Set 4 | kuytun
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | hearst
# Processing Record 22 of Set 4 | savannah bight
# Processing Record 23 of Set 4 | baykit
# Processing Record 24 of Set 4 | kuna
# Processing Record 25 of Set 4 | podgornoye
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | tual
# Processing Record 30 of Set 4 | yulara
# Processing Record 31 of Set 4 | sibu
# Processing Record 32 of Set 4 | rundu
# Processing Record 33 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 4 | chiang rai
# Processing Record 35 of Set 4 | kapaa
# Processing Record 36 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 4 | yumbing
# Processing Record 39 of Set 4 | hwange
# Processing Record 40 of Set 4 | hilo
# Processing Record 41 of Set 4 | manokwari
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | vredendal
# Processing Record 44 of Set 4 | mount isa
# Processing Record 45 of Set 4 | babol
# Processing Record 46 of Set 4 | mallama
# City not found. Skipping...
# Processing Record 47 of Set 4 | rafaela
# Processing Record 48 of Set 4 | noumea
# Processing Record 49 of Set 4 | port blair
# Processing Record 50 of Set 4 | kalmunai
# Processing Record 1 of Set 5 | san quintin
# Processing Record 2 of Set 5 | harer
# Processing Record 3 of Set 5 | port-gentil
# Processing Record 4 of Set 5 | ingham
# Processing Record 5 of Set 5 | smolenskaya
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | caborca
# Processing Record 8 of Set 5 | kamaishi
# Processing Record 9 of Set 5 | codrington
# Processing Record 10 of Set 5 | mahebourg
# Processing Record 11 of Set 5 | geraldton
# Processing Record 12 of Set 5 | chiang khong
# Processing Record 13 of Set 5 | asyut
# Processing Record 14 of Set 5 | matamoros
# Processing Record 15 of Set 5 | waw
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | shakiso
# Processing Record 19 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 20 of Set 5 | kotka
# Processing Record 21 of Set 5 | batesville
# Processing Record 22 of Set 5 | guarapari
# Processing Record 23 of Set 5 | ayan
# Processing Record 24 of Set 5 | saint-joseph
# Processing Record 25 of Set 5 | verkhoyansk
# Processing Record 26 of Set 5 | tshikapa
# Processing Record 27 of Set 5 | upernavik
# Processing Record 28 of Set 5 | bardiyah
# Processing Record 29 of Set 5 | fairbanks
# Processing Record 30 of Set 5 | guerrero negro
# Processing Record 31 of Set 5 | surt
# Processing Record 32 of Set 5 | bastrop
# Processing Record 33 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 5 | moroni
# Processing Record 35 of Set 5 | lagoa
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | chiredzi
# Processing Record 38 of Set 5 | honningsvag
# Processing Record 39 of Set 5 | provideniya
# Processing Record 40 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 5 | bargi
# Processing Record 42 of Set 5 | sheltozero
# Processing Record 43 of Set 5 | port hardy
# Processing Record 44 of Set 5 | camocim
# Processing Record 45 of Set 5 | cherskiy
# Processing Record 46 of Set 5 | ketchikan
# Processing Record 47 of Set 5 | rjukan
# Processing Record 48 of Set 5 | mmabatho
# Processing Record 49 of Set 5 | xiongshi
# City not found. Skipping...
# Processing Record 50 of Set 5 | tezu
# Processing Record 1 of Set 6 | kandi
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | pankovka
# Processing Record 4 of Set 6 | torbay
# Processing Record 5 of Set 6 | planaltina
# Processing Record 6 of Set 6 | longyearbyen
# Processing Record 7 of Set 6 | santiago de cao
# Processing Record 8 of Set 6 | caravelas
# Processing Record 9 of Set 6 | veraval
# Processing Record 10 of Set 6 | tuy hoa
# Processing Record 11 of Set 6 | honiara
# Processing Record 12 of Set 6 | san policarpo
# Processing Record 13 of Set 6 | vila franca do campo
# Processing Record 14 of Set 6 | tazovskiy
# Processing Record 15 of Set 6 | port elizabeth
# Processing Record 16 of Set 6 | corlu
# Processing Record 17 of Set 6 | chernyshevskiy
# Processing Record 18 of Set 6 | manono
# Processing Record 19 of Set 6 | aykhal
# Processing Record 20 of Set 6 | ancud
# Processing Record 21 of Set 6 | tandalti
# Processing Record 22 of Set 6 | aklavik
# Processing Record 23 of Set 6 | humaita
# Processing Record 24 of Set 6 | batemans bay
# Processing Record 25 of Set 6 | abonnema
# Processing Record 26 of Set 6 | zyryanka
# Processing Record 27 of Set 6 | san carlos
# Processing Record 28 of Set 6 | guane
# Processing Record 29 of Set 6 | farrukhnagar
# Processing Record 30 of Set 6 | bandarbeyla
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | klaksvik
# Processing Record 33 of Set 6 | komsomolskiy
# Processing Record 34 of Set 6 | mehamn
# Processing Record 35 of Set 6 | indianola
# Processing Record 36 of Set 6 | uarini
# Processing Record 37 of Set 6 | monrovia
# Processing Record 38 of Set 6 | gat
# Processing Record 39 of Set 6 | arman
# Processing Record 40 of Set 6 | maumere
# Processing Record 41 of Set 6 | faanui
# Processing Record 42 of Set 6 | roald
# Processing Record 43 of Set 6 | prince rupert
# Processing Record 44 of Set 6 | bubaque
# Processing Record 45 of Set 6 | diapaga
# Processing Record 46 of Set 6 | karratha
# Processing Record 47 of Set 6 | apt
# Processing Record 48 of Set 6 | tiznit
# Processing Record 49 of Set 6 | kaitangata
# Processing Record 50 of Set 6 | maragogi
# Processing Record 1 of Set 7 | narsaq
# Processing Record 2 of Set 7 | tramore
# Processing Record 3 of Set 7 | nhulunbuy
# Processing Record 4 of Set 7 | mirnyy
# Processing Record 5 of Set 7 | vestmannaeyjar
# Processing Record 6 of Set 7 | antalaha
# Processing Record 7 of Set 7 | muisne
# Processing Record 8 of Set 7 | tura
# Processing Record 9 of Set 7 | constitucion
# Processing Record 10 of Set 7 | christchurch
# Processing Record 11 of Set 7 | coquimbo
# Processing Record 12 of Set 7 | kouroussa
# Processing Record 13 of Set 7 | deniliquin
# Processing Record 14 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 7 | stettler
# Processing Record 16 of Set 7 | calabar
# Processing Record 17 of Set 7 | ust-ilimsk
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | cururupu
# Processing Record 20 of Set 7 | ibra
# Processing Record 21 of Set 7 | muros
# Processing Record 22 of Set 7 | smithers
# Processing Record 23 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 7 | berlevag
# Processing Record 25 of Set 7 | moose factory
# Processing Record 26 of Set 7 | mao
# Processing Record 27 of Set 7 | xiamen
# Processing Record 28 of Set 7 | coxim
# Processing Record 29 of Set 7 | kardla
# Processing Record 30 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 31 of Set 7 | tototlan
# Processing Record 32 of Set 7 | puerto madryn
# Processing Record 33 of Set 7 | nanortalik
# Processing Record 34 of Set 7 | isangel
# Processing Record 35 of Set 7 | palmer
# Processing Record 36 of Set 7 | banjar
# Processing Record 37 of Set 7 | cairns
# Processing Record 38 of Set 7 | talnakh
# Processing Record 39 of Set 7 | esfarayen
# Processing Record 40 of Set 7 | san juan
# Processing Record 41 of Set 7 | pombas
# Processing Record 42 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 7 | hanna
# Processing Record 44 of Set 7 | hofn
# Processing Record 45 of Set 7 | kahului
# Processing Record 46 of Set 7 | nalut
# Processing Record 47 of Set 7 | carnarvon
# Processing Record 48 of Set 7 | umea
# Processing Record 49 of Set 7 | teahupoo
# Processing Record 50 of Set 7 | nizwa
# Processing Record 1 of Set 8 | margate
# Processing Record 2 of Set 8 | tucuma
# Processing Record 3 of Set 8 | makakilo city
# Processing Record 4 of Set 8 | lar
# Processing Record 5 of Set 8 | namatanai
# Processing Record 6 of Set 8 | axim
# Processing Record 7 of Set 8 | kloulklubed
# Processing Record 8 of Set 8 | sulangan
# Processing Record 9 of Set 8 | van buren
# Processing Record 10 of Set 8 | santa cruz
# Processing Record 11 of Set 8 | tuktoyaktuk
# Processing Record 12 of Set 8 | santa vitoria
# Processing Record 13 of Set 8 | talakan
# Processing Record 14 of Set 8 | souillac
# Processing Record 15 of Set 8 | shache
# Processing Record 16 of Set 8 | saint-francois
# Processing Record 17 of Set 8 | riyadh
# Processing Record 18 of Set 8 | labuhan
# Processing Record 19 of Set 8 | alice springs
# Processing Record 20 of Set 8 | dingle
# Processing Record 21 of Set 8 | gorontalo
# Processing Record 22 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 23 of Set 8 | dondo
# Processing Record 24 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 8 | polunochnoye
# Processing Record 27 of Set 8 | ternate
# Processing Record 28 of Set 8 | the valley
# Processing Record 29 of Set 8 | jagdalpur
# Processing Record 30 of Set 8 | lodwar
# Processing Record 31 of Set 8 | magrath
# Processing Record 32 of Set 8 | almaznyy
# Processing Record 33 of Set 8 | chippewa falls
# Processing Record 34 of Set 8 | mahon
# Processing Record 35 of Set 8 | mogocha
# Processing Record 36 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 8 | aguimes
# Processing Record 38 of Set 8 | victoria
# Processing Record 39 of Set 8 | port hedland
# Processing Record 40 of Set 8 | japura
# Processing Record 41 of Set 8 | ozieri
# Processing Record 42 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 8 | tabuk
# Processing Record 44 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 8 | balkanabat
# Processing Record 46 of Set 8 | kracheh
# City not found. Skipping...
# Processing Record 47 of Set 8 | san jose
# Processing Record 48 of Set 8 | halifax
# Processing Record 49 of Set 8 | doha
# Processing Record 50 of Set 8 | stabat
# Processing Record 1 of Set 9 | dapaong
# Processing Record 2 of Set 9 | aripuana
# Processing Record 3 of Set 9 | ridgecrest
# Processing Record 4 of Set 9 | pangkalanbuun
# Processing Record 5 of Set 9 | la spezia
# Processing Record 6 of Set 9 | villa union
# Processing Record 7 of Set 9 | kavaratti
# Processing Record 8 of Set 9 | necochea
# Processing Record 9 of Set 9 | touba
# Processing Record 10 of Set 9 | los llanos de aridane
# Processing Record 11 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 9 | lerwick
# Processing Record 13 of Set 9 | iqaluit
# Processing Record 14 of Set 9 | mount gambier
# Processing Record 15 of Set 9 | ostrovnoy
# Processing Record 16 of Set 9 | richards bay
# Processing Record 17 of Set 9 | stromness
# Processing Record 18 of Set 9 | abha
# Processing Record 19 of Set 9 | revda
# Processing Record 20 of Set 9 | ustye
# Processing Record 21 of Set 9 | tessalit
# Processing Record 22 of Set 9 | traverse city
# Processing Record 23 of Set 9 | uvat
# Processing Record 24 of Set 9 | trincomalee
# Processing Record 25 of Set 9 | kieta
# Processing Record 26 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 9 | kelheim
# Processing Record 28 of Set 9 | monywa
# Processing Record 29 of Set 9 | egvekinot
# Processing Record 30 of Set 9 | beringovskiy
# Processing Record 31 of Set 9 | general pico
# Processing Record 32 of Set 9 | port shepstone
# Processing Record 33 of Set 9 | auki
# Processing Record 34 of Set 9 | kuri
# Processing Record 35 of Set 9 | iskenderun
# Processing Record 36 of Set 9 | kaseda
# Processing Record 37 of Set 9 | yongan
# Processing Record 38 of Set 9 | chifeng
# Processing Record 39 of Set 9 | guanica
# Processing Record 40 of Set 9 | moron
# Processing Record 41 of Set 9 | udachnyy
# Processing Record 42 of Set 9 | huarmey
# Processing Record 43 of Set 9 | broome
# Processing Record 44 of Set 9 | cajazeiras
# Processing Record 45 of Set 9 | champerico
# Processing Record 46 of Set 9 | lixourion
# Processing Record 47 of Set 9 | port macquarie
# Processing Record 48 of Set 9 | angoche
# Processing Record 49 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 9 | okhotsk
# Processing Record 1 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 2 of Set 10 | henties bay
# Processing Record 3 of Set 10 | linxia
# Processing Record 4 of Set 10 | bathsheba
# Processing Record 5 of Set 10 | san benito
# Processing Record 6 of Set 10 | del rio
# Processing Record 7 of Set 10 | mastic beach
# Processing Record 8 of Set 10 | dongsheng
# Processing Record 9 of Set 10 | xinzhi
# Processing Record 10 of Set 10 | iralaya
# Processing Record 11 of Set 10 | elko
# Processing Record 12 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 10 | uyemskiy
# Processing Record 14 of Set 10 | lompoc
# Processing Record 15 of Set 10 | mulege
# Processing Record 16 of Set 10 | taoudenni
# Processing Record 17 of Set 10 | santa rosa
# Processing Record 18 of Set 10 | ust-nera
# Processing Record 19 of Set 10 | boyolangu
# Processing Record 20 of Set 10 | nantucket
# Processing Record 21 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 22 of Set 10 | marystown
# Processing Record 23 of Set 10 | ouango
# Processing Record 24 of Set 10 | tilichiki
# Processing Record 25 of Set 10 | ondangwa
# Processing Record 26 of Set 10 | addis abeba
# Processing Record 27 of Set 10 | ust-kuyga
# Processing Record 28 of Set 10 | boende
# Processing Record 29 of Set 10 | quang ngai
# Processing Record 30 of Set 10 | maues
# Processing Record 31 of Set 10 | deputatskiy
# Processing Record 32 of Set 10 | steamboat springs
# Processing Record 33 of Set 10 | brae
# Processing Record 34 of Set 10 | gigmoto
# Processing Record 35 of Set 10 | miles city
# Processing Record 36 of Set 10 | homer
# Processing Record 37 of Set 10 | baijiantan
# Processing Record 38 of Set 10 | puerto del rosario
# Processing Record 39 of Set 10 | lac-megantic
# Processing Record 40 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 10 | nianzishan
# Processing Record 42 of Set 10 | jiangyou
# Processing Record 43 of Set 10 | pakxe
# Processing Record 44 of Set 10 | oytal
# Processing Record 45 of Set 10 | camacha
# Processing Record 46 of Set 10 | kerman
# Processing Record 47 of Set 10 | tsogni
# Processing Record 48 of Set 10 | meulaboh
# Processing Record 49 of Set 10 | zalantun
# Processing Record 50 of Set 10 | vila velha
# Processing Record 1 of Set 11 | hamilton
# Processing Record 2 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 11 | kisangani
# Processing Record 4 of Set 11 | empalme
# Processing Record 5 of Set 11 | lebedinyy
# Processing Record 6 of Set 11 | rocha
# Processing Record 7 of Set 11 | tarauaca
# Processing Record 8 of Set 11 | kulhudhuffushi
# Processing Record 9 of Set 11 | marawi
# Processing Record 10 of Set 11 | sisimiut
# Processing Record 11 of Set 11 | nome
# Processing Record 12 of Set 11 | tchibanga
# Processing Record 13 of Set 11 | hounde
# Processing Record 14 of Set 11 | kedrovyy
# Processing Record 15 of Set 11 | curuguaty
# Processing Record 16 of Set 11 | voloshka
# Processing Record 17 of Set 11 | mitu
# Processing Record 18 of Set 11 | presidencia roque saenz pena
# Processing Record 19 of Set 11 | jinji
# Processing Record 20 of Set 11 | laguna
# Processing Record 21 of Set 11 | sinnamary
# Processing Record 22 of Set 11 | lebedyn
# Processing Record 23 of Set 11 | kiama
# Processing Record 24 of Set 11 | portland
# Processing Record 25 of Set 11 | bodden town
# Processing Record 26 of Set 11 | haines junction
# Processing Record 27 of Set 11 | nuuk
# Processing Record 28 of Set 11 | flinders
# Processing Record 29 of Set 11 | ndola
# Processing Record 30 of Set 11 | tanuma
# Processing Record 31 of Set 11 | saint anthony
# Processing Record 32 of Set 11 | mitsamiouli
# Processing Record 33 of Set 11 | fortuna
# Processing Record 34 of Set 11 | porec
# Processing Record 35 of Set 11 | rafsanjan
# Processing Record 36 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 11 | petatlan
# Processing Record 38 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 11 | katha
# City not found. Skipping...
# Processing Record 40 of Set 11 | mafinga
# Processing Record 41 of Set 11 | pacific grove
# Processing Record 42 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 11 | bello
# Processing Record 45 of Set 11 | phnum penh
# City not found. Skipping...
# Processing Record 46 of Set 11 | port-cartier
# Processing Record 47 of Set 11 | panjwin
# City not found. Skipping...
# Processing Record 48 of Set 11 | faya
# Processing Record 49 of Set 11 | eskilstuna
# Processing Record 50 of Set 11 | westport
# Processing Record 1 of Set 12 | sobolevo
# Processing Record 2 of Set 12 | bud
# Processing Record 3 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 4 of Set 12 | flin flon
# Processing Record 5 of Set 12 | suslovo
# Processing Record 6 of Set 12 | bengkulu
# Processing Record 7 of Set 12 | ulladulla
# Processing Record 8 of Set 12 | bilma
# Processing Record 9 of Set 12 | parrita
# Processing Record 10 of Set 12 | aleksandrovskiy zavod
# Processing Record 11 of Set 12 | ormara
# Processing Record 12 of Set 12 | buenos aires
# Processing Record 13 of Set 12 | emba
# Processing Record 14 of Set 12 | foumban
# Processing Record 15 of Set 12 | tamandare
# Processing Record 16 of Set 12 | ribnica
# Processing Record 17 of Set 12 | naze
# Processing Record 18 of Set 12 | bankja
# City not found. Skipping...
# Processing Record 19 of Set 12 | ucluelet
# Processing Record 20 of Set 12 | abaza
# Processing Record 21 of Set 12 | poso
# Processing Record 22 of Set 12 | nemuro
# Processing Record 23 of Set 12 | trairi
# Processing Record 24 of Set 12 | gizo
# Processing Record 25 of Set 12 | tombouctou
# Processing Record 26 of Set 12 | isfana
# Processing Record 27 of Set 12 | voskresenskoye
# Processing Record 28 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 30 of Set 12 | weinan
# Processing Record 31 of Set 12 | nouakchott
# Processing Record 32 of Set 12 | mbandaka
# Processing Record 33 of Set 12 | tarata
# Processing Record 34 of Set 12 | pittsburg
# Processing Record 35 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 12 | fayaoue
# Processing Record 37 of Set 12 | kavieng
# Processing Record 38 of Set 12 | vallenar
# Processing Record 39 of Set 12 | polis
# Processing Record 40 of Set 12 | rongcheng
# Processing Record 41 of Set 12 | paamiut
# Processing Record 42 of Set 12 | montepuez
# Processing Record 43 of Set 12 | luanda
# Processing Record 44 of Set 12 | sigli
# Processing Record 45 of Set 12 | teya
# Processing Record 46 of Set 12 | labrea
# Processing Record 47 of Set 12 | graaff-reinet
# Processing Record 48 of Set 12 | basco
# Processing Record 49 of Set 12 | khani
# Processing Record 50 of Set 12 | kalanguy
# Processing Record 1 of Set 13 | abu samrah
# Processing Record 2 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 13 | siddipet
# Processing Record 4 of Set 13 | belmonte
# Processing Record 5 of Set 13 | raga
# Processing Record 6 of Set 13 | acarau
# Processing Record 7 of Set 13 | erzincan
# Processing Record 8 of Set 13 | artyom
# Processing Record 9 of Set 13 | bilibino
# Processing Record 10 of Set 13 | dunaharaszti
# Processing Record 11 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 12 of Set 13 | karlskrona
# Processing Record 13 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 13 | zhanakorgan
# Processing Record 15 of Set 13 | coahuayana
# Processing Record 16 of Set 13 | beian
# Processing Record 17 of Set 13 | vanimo
# Processing Record 18 of Set 13 | umarkot
# Processing Record 19 of Set 13 | san andres
# Processing Record 20 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 13 | romitan
# Processing Record 22 of Set 13 | marseille
# Processing Record 23 of Set 13 | ahipara
# Processing Record 24 of Set 13 | comodoro rivadavia
# Processing Record 25 of Set 13 | saint-leu
# Processing Record 26 of Set 13 | tahe
# Processing Record 27 of Set 13 | lasa
# Processing Record 28 of Set 13 | aswan
# Processing Record 29 of Set 13 | nakonde
# Processing Record 30 of Set 13 | juneau
# Processing Record 31 of Set 13 | la palma
# Processing Record 32 of Set 13 | pimentel
# Processing Record 33 of Set 13 | paita
# Processing Record 34 of Set 13 | beachwood
# Processing Record 35 of Set 13 | oyama
# Processing Record 36 of Set 13 | charlestown
# Processing Record 37 of Set 13 | inhambane
# Processing Record 38 of Set 13 | achacachi
# Processing Record 39 of Set 13 | asau
# Processing Record 40 of Set 13 | ziyang
# Processing Record 41 of Set 13 | russell
# Processing Record 42 of Set 13 | lata
# Processing Record 43 of Set 13 | pangody
# Processing Record 44 of Set 13 | moyale
# Processing Record 45 of Set 13 | waterloo
# Processing Record 46 of Set 13 | carupano
# Processing Record 47 of Set 13 | beya
# Processing Record 48 of Set 13 | andenes
# Processing Record 49 of Set 13 | quatre cocos
# Processing Record 50 of Set 13 | den helder
# Processing Record 1 of Set 14 | hovd
# Processing Record 2 of Set 14 | uni
# Processing Record 3 of Set 14 | anadyr
# Processing Record 4 of Set 14 | binzhou
# Processing Record 5 of Set 14 | mishan
# Processing Record 6 of Set 14 | la asuncion
# Processing Record 7 of Set 14 | san cristobal
# Processing Record 8 of Set 14 | kondopoga
# Processing Record 9 of Set 14 | phan thiet
# Processing Record 10 of Set 14 | mogadishu
# Processing Record 11 of Set 14 | archidona
# Processing Record 12 of Set 14 | chongwe
# Processing Record 13 of Set 14 | filingue
# Processing Record 14 of Set 14 | slantsy
# Processing Record 15 of Set 14 | salalah
# Processing Record 16 of Set 14 | biak
# Processing Record 17 of Set 14 | urumqi
# Processing Record 18 of Set 14 | dawei
# Processing Record 19 of Set 14 | suba
# Processing Record 20 of Set 14 | surenavan
# Processing Record 21 of Set 14 | barendrecht
# Processing Record 22 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 23 of Set 14 | bac lieu
# Processing Record 24 of Set 14 | antofagasta
# Processing Record 25 of Set 14 | villarrobledo
# Processing Record 26 of Set 14 | qaqortoq
# Processing Record 27 of Set 14 | lubumbashi
# Processing Record 28 of Set 14 | sarandi
# Processing Record 29 of Set 14 | channel-port aux basques
# Processing Record 30 of Set 14 | inirida
# Processing Record 31 of Set 14 | bria
# Processing Record 32 of Set 14 | leme
# Processing Record 33 of Set 14 | sola
# Processing Record 34 of Set 14 | tres arroyos
# Processing Record 35 of Set 14 | kaoma
# Processing Record 36 of Set 14 | ocos
# Processing Record 37 of Set 14 | druzhba
# Processing Record 38 of Set 14 | merauke
# Processing Record 39 of Set 14 | bijie
# Processing Record 40 of Set 14 | mayumba
# Processing Record 41 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 42 of Set 14 | kaka
# Processing Record 43 of Set 14 | mount vernon
# Processing Record 44 of Set 14 | setermoen
# Processing Record 45 of Set 14 | assiniboia
# Processing Record 46 of Set 14 | buala
# Processing Record 47 of Set 14 | west bay
# Processing Record 48 of Set 14 | tazmalt
# Processing Record 49 of Set 14 | raudeberg
# Processing Record 50 of Set 14 | berezovyy
# Processing Record 1 of Set 15 | santa maria
# Processing Record 2 of Set 15 | golesti
# Processing Record 3 of Set 15 | mancio lima
# Processing Record 4 of Set 15 | erenhot
# Processing Record 5 of Set 15 | yarovoye
# Processing Record 6 of Set 15 | ayagoz
# Processing Record 7 of Set 15 | ponoka
# Processing Record 8 of Set 15 | sajobabony
# Processing Record 9 of Set 15 | borogontsy
# Processing Record 10 of Set 15 | teguise
# Processing Record 11 of Set 15 | tiarei
# Processing Record 12 of Set 15 | boa vista
# Processing Record 13 of Set 15 | gravdal
# Processing Record 14 of Set 15 | hambantota
# Processing Record 15 of Set 15 | lere
# Processing Record 16 of Set 15 | xining
# Processing Record 17 of Set 15 | kushima
# Processing Record 18 of Set 15 | shemysheyka
# Processing Record 19 of Set 15 | dzhankoy
# Processing Record 20 of Set 15 | shu
# Processing Record 21 of Set 15 | gogrial
# Processing Record 22 of Set 15 | ngunguru
# Processing Record 23 of Set 15 | ambilobe
# Processing Record 24 of Set 15 | xapuri
# Processing Record 25 of Set 15 | valparaiso
# Processing Record 26 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 15 | huanren
# Processing Record 28 of Set 15 | chastoozerye
# City not found. Skipping...
# Processing Record 29 of Set 15 | am timan
# Processing Record 30 of Set 15 | ulaanbaatar
# Processing Record 31 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 15 | biltine
# Processing Record 33 of Set 15 | grand gaube
# Processing Record 34 of Set 15 | qasigiannguit
# Processing Record 35 of Set 15 | otane
# Processing Record 36 of Set 15 | pizarro
# Processing Record 37 of Set 15 | sorong
# Processing Record 38 of Set 15 | rio grande city
# Processing Record 39 of Set 15 | el tigre
# Processing Record 40 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 15 | la uribe
# City not found. Skipping...
# Processing Record 42 of Set 15 | djibo
# Processing Record 43 of Set 15 | ossora
# Processing Record 44 of Set 15 | sibolga
# Processing Record 45 of Set 15 | conde
# Processing Record 46 of Set 15 | hailey
# Processing Record 47 of Set 15 | dumai
# Processing Record 48 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 15 | byron bay
# Processing Record 50 of Set 15 | portalegre
# Processing Record 1 of Set 16 | chinsali
# Processing Record 2 of Set 16 | dien bien
# City not found. Skipping...
# Processing Record 3 of Set 16 | rawson
# Processing Record 4 of Set 16 | zunyi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Miri   4.4148  114.0089     77.14       100          40        4.61
# 1         Lebu -37.6167  -73.6500     59.76        92          17       12.68
# 2        Avera  33.1940  -82.5271     70.72        72         100       14.88
# 3        Takab  36.4009   47.1133     24.60        73          50        2.17
# 4  Santo Tomas  14.1079  121.1414     84.56        57          85       10.00
# 5     Balkhash  46.8440   74.9804      2.01        71           0       17.90
# 6      Mataura -46.1927  168.8643     49.30        99         100        3.11
# 7      Ushuaia -54.8000  -68.3000     44.26        65          75       20.71
# 8        Adrar  20.5022  -10.0711     60.93        19           0       10.22
# 9     Lorengau  -2.0226  147.2712     84.72        64         100        9.08
#
#   Country Current Description
# 0      MY    scattered clouds
# 1      CL          few clouds
# 2      US     overcast clouds
# 3      IR    scattered clouds
# 4      PH     overcast clouds
# 5      KZ           clear sky
# 6      NZ          light rain
# 7      AR       broken clouds
# 8      MR           clear sky
# 9      PG     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
